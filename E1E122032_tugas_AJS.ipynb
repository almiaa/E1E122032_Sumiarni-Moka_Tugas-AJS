# %% [markdown]
# <a href="https://colab.research.google.com/github/almiaa/Tugas-AJS/blob/main/E1E122032_tugas_AJS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

# %%
import tweepy
import requests
import pandas as pd

# %%
twitter_data = []

# %%
payload = {
    'api_key' : '8247234f9be154e7c68edae729d7479e',
    'query' : 'jimin',
    'num' : '100'
}

response = requests.get(
    'https://api.scraperapi.com/structured/twitter/search', params = payload
)
data = response.json()

# %%
data
# Out:
# {'search_information': {'query_displayed': 'site:twitter.com "jimin"'},
#  'images': [{'position': 0,
#    'link': 'https://twitter.com/CNN/status/1643542785763553280',
#    'title': 'CNN on X: "Other members of BTS have gone solo, but none as ...',
#    'source': 'X.com',
#    'thumbnail': 'data:image/jpeg;base64,...'},
#   {'position': 1,
#    'link': 'https://twitter.com/PamelaVilches8',
#    'title': 'Bella💙JIMIN (BTS) (@PamelaVilches8) / X',
#    'source': 'X.com',
#    'thumbnail': 'data:image/jpeg;base64,...'},
#   {'position': 2,
#    'link': 'https://twitter.com/ampijimin',
#    'title': 'Jimin Noona (Very Slow) (@ampijimin) / X',
#    'source': 'X.com',
#    'thumbnail': 'data:image/jpeg;base64,...'}],
#  'organic_results': [{'position': 3,
#    'title': 'Jimin Global (@JiminGlobal) / X',
#    'snippet': 'Union fanbase for Park #Jimin #지민 of #BTS #방탄소년단. #BTSARMY. Updates. News. Features. Rewind. Stats. Events. Projects. Photos. Videos.',
#    'highlighs': ['Jimin'],
# ...

# %%
data.keys()
# Out:
# dict_keys(['search_information', 'images', 'organic_results', 'pagination'])

# %%
data['search_information']
# Out:
# {'query_displayed': 'site:twitter.com "jimin"'}

# %%
data['organic_results']
# Out:
# [{'position': 3,
#   'title': 'Jimin Global (@JiminGlobal) / X',
#   'snippet': 'Union fanbase for Park #Jimin #지민 of #BTS #방탄소년단. #BTSARMY. Updates. News. Features. Rewind. Stats. Events. Projects. Photos. Videos.',
#   'highlighs': ['Jimin'],
#   'link': 'https://twitter.com/JiminGlobal',
#   'displayed_link': 'https://twitter.com › JiminGlobal'},
#  {'position': 4,
#   'title': 'J I M I N ¹³ Hot 100 #1 Artist (@jiminmochipower) ...',
#   'snippet': 'Fan account for Park Jimin.',
#   'highlighs': ['Jimin'],
#   'link': 'https://twitter.com/jiminmochipower',
#   'displayed_link': 'https://twitter.com › jiminmochipower'},
#  {'position': 5,
#   'title': '𝟏𝟑 (@pjmfilmz) / X',
#   'snippet': 'JIMIN LOVERS Boost your support for Jimin by connecting with the various fanbases highlighted in this video and gear up for PJM2!',
#   'highlighs': ['JIMIN', 'Jimin'],
#   'link': 'https://twitter.com/pjmfilmz',
#   'displayed_link': 'https://twitter.com › pjmfilmz'},
#  {'position': 6,
# ...

# %%
all_tweets = data['organic_results']
for tweet in all_tweets:
  twitter_data.append(tweet)

# %%
df = pd.DataFrame(twitter_data)
df.to_json('tweets.json', orient = 'index')
print("file exported")
# Out:
# file exported

# %%
df
# Out:
#     position                                              title  \
# 0          3                    Jimin Global (@JiminGlobal) / X
# 1          4  J I M I N ¹³ Hot 100 #1 Artist (@jiminmochipow...
# 2          5                                 𝟏𝟑 (@pjmfilmz) / X
# 3          6            JIMIN DATA | TEMP. REST (@PJM_data) / X
# 4          7                       PARK JIMIN (@jiminie_up) / X
# ..       ...                                                ...
# 94        97  Yes ✨Jimin In Berets✨ Is This Important ⁷ (@Ji...
# 95        98                          JIMIN (@jiminstuffs_) / X
# 96        99       Park Jimin PH 🇵🇭 FACE BY JIMIN IS COMING ...
# 97       100  'Study with BTS' | Jimin Our Class president P...
# 98       101                        Jimin Lee-Bui (@jmninc) / X
#
#                                               snippet       highlighs  \
# 0   Union fanbase for Park #Jimin #지민 of #BTS #방탄소...         [Jimin]
# ...

# %%
df.to_excel("data_tweet.xlsx", sheet_name = 'Sheet_name_1')
